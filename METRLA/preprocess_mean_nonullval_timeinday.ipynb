0.000000   0.000000
# ...                        ...        ...        ...        ...        ...
# 2012-06-27 23:35:00  66.333333  62.444444  66.777778  64.888889  69.666667
# 2012-06-27 23:40:00  67.250000  59.375000  66.000000  61.250000  69.000000
# 2012-06-27 23:45:00  66.000000  62.666667  68.666667  63.333333  67.444444
# 2012-06-27 23:50:00  65.625000  66.375000  69.500000  63.000000  67.875000
# 2012-06-27 23:55:00  64.222222  66.444444  68.444444  63.555556  68.666667
#
#                         769373
# 2012-03-01 00:00:00  61.875000
# 2012-03-01 00:05:00  62.875000
# 2012-03-01 00:10:00  62.000000
# 2012-03-01 00:15:00   0.000000
# 2012-03-01 00:20:00   0.000000
# ...                        ...
# 2012-06-27 23:35:00  62.333333
# 2012-06-27 23:40:00  62.000000
# 2012-06-27 23:45:00  61.222222
# 2012-06-27 23:50:00  63.500000
# 2012-06-27 23:55:00  61.777778
#
# [34272 rows x 207 columns]

# %%
timeslots = pd.date_range('2012-03-01 00:00:00', '2012-06-27 23:55:00', freq='5min')
print(len(timeslots))
days = pd.date_range('2012-03-01 00:00:00', '2012-06-27 23:55:00', freq='1D')
print(len(days), 0.8*len(days))
train_days = pd.date_range('2012-03-01 00:00:00', '2012-06-03 23:55:00', freq='1D')
print(len(train_days))
print(len(timeslots), timeslots[0], timeslots[-1])
list1 = [t.strftime('%Y-%m-%d %H:%M:%S')  for t in timeslots]
print(len(list1))
list2 = [pd.to_datetime(str(x)).strftime('%Y-%m-%d %H:%M:%S')  for x in df.index.values]
print(len(list2))
print(set(list1) - set(list2))
# Out:
# 34272
# 119 95.2
# 95
# 34272 2012-03-01 00:00:00 2012-06-27 23:55:00
# 34272
# 34272
# set()

# %%
data = df.stack().reset_index()
data.columns = ['timestamp', 'sensorid', 'speed']
data.dtypes
# Out:
# timestamp    datetime64[ns]
# sensorid             object
# speed               float64
# dtype: object

# %%
data['timeinday'] = (data['timestamp'].values - data['timestamp'].values.astype("datetime64[D]")) / np.timedelta64(1, "D")
data
# Out:
#                   timestamp sensorid      speed  timeinday
# 0       2012-03-01 00:00:00   773869  64.375000   0.000000
# 1       2012-03-01 00:00:00   767541  67.625000   0.000000
# 2       2012-03-01 00:00:00   767542  67.125000   0.000000
# 3       2012-03-01 00:00:00   717447  61.500000   0.000000
# 4       2012-03-01 00:00:00   717446  66.875000   0.000000
# ...                     ...      ...        ...        ...
# 7094299 2012-06-27 23:55:00   717592  66.444444   0.996528
# 7094300 2012-06-27 23:55:00   717595  68.444444   0.996528
# 7094301 2012-06-27 23:55:00   772168  63.555556   0.996528
# 7094302 2012-06-27 23:55:00   718141  68.666667   0.996528
# 7094303 2012-06-27 23:55:00   769373  61.777778   0.996528
#
# [7094304 rows x 4 columns]

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data['weekdaytime'] = data['timestamp'].dt.weekday * 288 + (data['timestamp'].dt.hour * 60 + data['timestamp'].dt.minute)//5
data
# Out:
#                   timestamp sensorid      speed  timeinday  weekdaytime
# 0       2012-03-01 00:00:00   773869  64.375000   0.000000          864
# 1       2012-03-01 00:00:00   767541  67.625000   0.000000          864
# 2       2012-03-01 00:00:00   767542  67.125000   0.000000          864
# 3       2012-03-01 00:00:00   717447  61.500000   0.000000          864
# 4       2012-03-01 00:00:00   717446  66.875000   0.000000          864
# ...                     ...      ...        ...        ...          ...
# 7094299 2012-06-27 23:55:00   717592  66.444444   0.996528          863
# 7094300 2012-06-27 23:55:00   717595  68.444444   0.996528          863
# 7094301 2012-06-27 23:55:00   772168  63.555556   0.996528          863
# 7094302 2012-06-27 23:55:00   718141  68.666667   0.996528          863
# 7094303 2012-06-27 23:55:00   769373  61.777778   0.996528          863
#
# [7094304 rows x 5 columns]

# %%
df_train = data[(data.timestamp >= '2012-03-01 00:00:00') & (data.timestamp <= '2012-06-03 23:55:00')]
df_train = df_train[['sensorid', 'weekdaytime', 'speed']]
df_train
# Out:
#         sensorid  weekdaytime      speed
# 0         773869          864  64.375000
# 1         767541          864  67.625000
# 2         767542          864  67.125000
# 3         717447          864  61.500000
# 4         717446          864  66.875000
# ...          ...          ...        ...
# 5663515   717592         2015  60.444444
# 5663516   717595         2015  68.777778
# 5663517   772168         2015  63.333333
# 5663518   718141         2015  68.666667
# 5663519   769373         2015  62.888889
#
# [5663520 rows x 3 columns]

# %%
def get_mean_without_null_values(data, null_val=0.):
    return data[data != null_val].mean()
df_train_avg = df_train.groupby(['sensorid', 'weekdaytime']).aggregate({'speed': get_mean_without_null_values}).reset_index()
df_train_avg
# Out:
#        sensorid  weekdaytime      speed
# 0        716328            0  66.794444
# 1        716328            1  66.896991
# 2        716328            2  66.592923
# 3        716328            3  66.475505
# 4        716328            4  66.430556
# ...         ...          ...        ...
# 417307   774204         2011  64.847222
# 417308   774204         2012  65.797980
# 417309   774204         2013  64.006313
# 417310   774204         2014  64.577381
# 417311   774204         2015  64.105655
#
# [417312 rows x 3 columns]

# %%
data_plus = pd.merge(data, df_train_avg, on=['sensorid', 'weekdaytime'], suffixes=(None, '_y'))
data_plus
# Out:
#                   timestamp sensorid      speed  timeinday  weekdaytime  \
# 0       2012-03-01 00:00:00   773869  64.375000   0.000000          864
# 1       2012-03-08 00:00:00   773869  66.777778   0.000000          864
# 2       2012-03-15 00:00:00   773869  66.750000   0.000000          864
# 3       2012-03-22 00:00:00   773869  59.666667   0.000000          864
# 4       2012-03-29 00:00:00   773869  64.444444   0.000000          864
# ...                     ...      ...        ...        ...          ...
# 7094299 2012-05-30 23:55:00   769373  62.444444   0.996528          863
# 7094300 2012-06-06 23:55:00   769373  58.444444   0.996528          863
# 7094301 2012-06-13 23:55:00   769373  63.500000   0.996528          863
# 7094302 2012-06-20 23:55:00   769373  61.250000   0.996528          863
# 7094303 2012-06-27 23:55:00   769373  61.777778   0.996528          863
#
#            speed_y
# 0        63.132937
# 1        63.132937
# 2        63.132937
# 3        63.132937
# 4        63.132937
# ...            ...
# 7094299  61.062118
# 7094300  61.062118
# 7094301  61.062118
# 7094302  61.062118
# 7094303  61.062118
#
# [7094304 rows x 6 columns]

# %%
sensorid_list = df.columns
timeslices = df.index
mux = pd.MultiIndex.from_product([timeslices, sensorid_list],names=['timestamp', 'sensorid'])
data_plus = data_plus.set_index(['timestamp', 'sensorid']).reindex(mux).reset_index()
data_plus = data_plus[['timestamp', 'sensorid', 'speed', 'timeinday', 'speed_y']]
data_plus
# Out:
#                   timestamp sensorid      speed  timeinday    speed_y
# 0       2012-03-01 00:00:00   773869  64.375000   0.000000  63.132937
# 1       2012-03-01 00:00:00   767541  67.625000   0.000000  64.867063
# 2       2012-03-01 00:00:00   767542  67.125000   0.000000  66.170635
# 3       2012-03-01 00:00:00   717447  61.500000   0.000000  61.943452
# 4       2012-03-01 00:00:00   717446  66.875000   0.000000  65.241071
# ...                     ...      ...        ...        ...        ...
# 7094299 2012-06-27 23:55:00   717592  66.444444   0.996528  62.377595
# 7094300 2012-06-27 23:55:00   717595  68.444444   0.996528  66.349054
# 7094301 2012-06-27 23:55:00   772168  63.555556   0.996528  64.207723
# 7094302 2012-06-27 23:55:00   718141  68.666667   0.996528  66.785409
# 7094303 2012-06-27 23:55:00   769373  61.777778   0.996528  61.062118
#
# [7094304 rows x 5 columns]

# %%
np.array_equal(data_plus['speed'].values.reshape(-1, 207), df.values)
# Out:
# True

# %%
store = pd.HDFStore("metr-la-plus.h5", 'w')
store.put('/df', data_plus)

# %%
df_reload = pd.HDFStore('../METRLA/metr-la-plus.h5')['/df']
df_reload
# Out:
#                   timestamp sensorid      speed  timeinday    speed_y
# 0       2012-03-01 00:00:00   773869  64.375000   0.000000  63.132937
# 1       2012-03-01 00:00:00   767541  67.625000   0.000000  64.867063
# 2       2012-03-01 00:00:00   767542  67.125000   0.000000  66.170635
# 3       2012-03-01 00:00:00   717447  61.500000   0.000000  61.943452
# 4       2012-03-01 00:00:00   717446  66.875000   0.000000  65.241071
# ...                     ...      ...        ...        ...        ...
# 7094299 2012-06-27 23:55:00   717592  66.444444   0.996528  62.377595
# 7094300 2012-06-27 23:55:00   717595  68.444444   0.996528  66.349054
# 7094301 2012-06-27 23:55:00   772168  63.555556   0.996528  64.207723
# 7094302 2012-06-27 23:55:00   718141  68.666667   0.996528  66.785409
# 7094303 2012-06-27 23:55:00   769373  61.777778   0.996528  61.062118
#
# [7094304 rows x 5 columns]

# %%
np.array_equal(df_reload['speed'].values.reshape(-1, 207), df.values)
# Out:
# True
