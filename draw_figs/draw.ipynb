# %%
import matplotlib.pyplot as plt
import numpy as np

m_list=np.arange(5, 26, step=5).astype("str")
d_list=np.arange(16, 81, step=16).astype("str")

m_mae_list_LA=[2.9682, 2.9675, 2.9657, 2.9528, 2.9798]
m_mape_list_LA=[8.2346, 8.2676, 8.1226, 8.0272, 8.3511]
m_rmse_list_LA=[6.1196, 6.1056, 6.0900, 6.0647, 6.1560]

m_mae_list_BAY=[1.5579, 1.7940, 1.5576, 1.5537, 1.6355]
m_mape_list_BAY=[3.4965, 3.9938, 3.5051, 3.4834, 3.6817]
m_rmse_list_BAY=[3.6155, 4.2137, 3.6247, 3.5958, 3.7503]

d_mae_list_LA=[2.9753, 2.9738, 2.9592, 2.9528, 2.9736]
d_mape_list_LA=[8.1571, 8.3102, 8.0307, 8.0272, 8.2708]
d_rmse_list_LA=[6.1215, 6.1253, 6.0807, 6.0647, 6.1357]

d_mae_list_BAY=[1.5507, 1.5672, 1.5561, 1.5537, 1.5456]
d_mape_list_BAY=[3.4909, 3.5360, 3.5173, 3.4834, 3.4716]
d_rmse_list_BAY=[3.5965, 3.6105, 3.6128, 3.5958, 3.5905]

def set_label(rects):
    for rect in rects:
        height = rect.get_height() # 获取⾼度
        plt.text(x = rect.get_x() + rect.get_width()/2, # ⽔平坐标
                 y = height + 0.002, # 竖直坐标
                 s = round(height, 3), # ⽂本
                 ha = 'center', # ⽔平居中
                 fontsize=20, 
                 fontproperties = "Times New Roman")
        
plt.figure(figsize=(6, 6))
plt.yticks(fontproperties = "Times New Roman", size = 30)
plt.xticks(fontproperties = "Times New Roman", size = 30)
plt.ylabel("Avg. RMSE", fontdict={"family" : "Times New Roman", "size": 35})
plt.xlabel(r"$d_m$", fontdict={"family" : "Times New Roman", "size": 45})
ax = plt.gca()
# ax.xaxis.set_label_position("top")
ax.xaxis.set_label_coords(0.5, 1.15)


# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#63a7f7", "#63a7f7", "#63a7f7", "#bcbd22", "#63a7f7", "#63a7f7"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#0868ac", "#0868ac", "#0868ac", "#bcbd22", "#0868ac", "#0868ac"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#1f77b4", "#1f77b4", "#1f77b4", "#bcbd22", "#1f77b4", "#1f77b4"])
bar1=plt.bar(d_list, d_rmse_list_LA, width=0.9, color=["#c2947a", "#c2947a", "#c2947a", "#FFD700", "#c2947a"])
# bar1=plt.bar(d_list, d_rmse_list_LA, width=0.9, color=["#008080", "#008080", "#008080", "#FFD700", "#008080"])
plt.ylim(6.04, 6.14)

# plt.savefig("./images/xx.png", dpi=300, bbox_inches='tight')
plt.show();

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize=(12, 6))
fig.subplots_adjust(wspace=0.05)  # adjust space between axes

m_list=np.arange(5, 26, step=5).astype("str")
d_list=np.arange(16, 81, step=16).astype("str")

m_mae_list_LA=[2.9682, 2.9675, 2.9657, 2.9528, 2.9798]
m_mape_list_LA=[8.2346, 8.2676, 8.1226, 8.0272, 8.3511]
m_rmse_list_LA=[6.1196, 6.1056, 6.0900, 6.0647, 6.1560]

d_mae_list_LA=[2.9753, 2.9738, 2.9592, 2.9528, 2.9736]
d_mape_list_LA=[8.1571, 8.3102, 8.0307, 8.0272, 8.2708]
d_rmse_list_LA=[6.1215, 6.1253, 6.0807, 6.0647, 6.1357]

def set_label(rects):
    for rect in rects:
        height = rect.get_height() # 获取⾼度
        plt.text(x = rect.get_x() + rect.get_width()/2, # ⽔平坐标
                 y = height + 0.002, # 竖直坐标
                 s = round(height, 3), # ⽂本
                 ha = 'center', # ⽔平居中
                 fontsize=20, 
                 fontproperties = "Times New Roman")

ax1.set_ylabel("Avg. RMSE", fontdict={"family" : "Times New Roman", "size": 35})
ax1.set_xlabel(r"$M$", fontdict={"family" : "Times New Roman", "size": 45})
ax1.xaxis.set_label_coords(0.5, 1.12)
ax2.set_xlabel(r"$d_m$", fontdict={"family" : "Times New Roman", "size": 45})
ax2.xaxis.set_label_coords(0.5, 1.15)
ax2.set_yticks([])

font = fm.FontProperties(family='Times New Roman', size=30)
for label in ax1.get_xticklabels():
    label.set_fontproperties(font)
for label in ax1.get_yticklabels():
    label.set_fontproperties(font)
for label in ax2.get_xticklabels():
    label.set_fontproperties(font)
for label in ax2.get_yticklabels():
    label.set_fontproperties(font)

# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#63a7f7", "#63a7f7", "#63a7f7", "#bcbd22", "#63a7f7", "#63a7f7"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#0868ac", "#0868ac", "#0868ac", "#bcbd22", "#0868ac", "#0868ac"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#1f77b4", "#1f77b4", "#1f77b4", "#bcbd22", "#1f77b4", "#1f77b4"])
# bar1=plt.bar(d_list, d_rmse_list_LA, width=0.9, color=["#008080", "#008080", "#008080", "#FFD700", "#008080"])

bar1=ax1.bar(m_list, m_rmse_list_LA, width=0.9, color=["#c2947a", "#c2947a", "#c2947a", "#FFD700", "#c2947a"])
bar2=ax2.bar(d_list, d_rmse_list_LA, width=0.9, color=["#c2947a", "#c2947a", "#c2947a", "#FFD700", "#c2947a"])
ax1.set_ylim(6.04, 6.16)
ax2.set_ylim(6.04, 6.16)

plt.savefig("./param_LA.png", dpi=300, bbox_inches='tight')
plt.show();

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=False, figsize=(12, 6))
fig.subplots_adjust(wspace=0.05)  # adjust space between axes

m_list=np.arange(5, 26, step=5).astype("str")
d_list=np.arange(16, 81, step=16).astype("str")

m_mae_list_BAY=[1.5579, 1.5540, 1.5576, 1.5537, 1.6355]
m_mape_list_BAY=[3.4965, 3.5429, 3.5051, 3.4834, 3.6817]
m_rmse_list_BAY=[3.6155, 3.6169, 3.6247, 3.5958, 3.7503]

d_mae_list_BAY=[1.5507, 1.5672, 1.5561, 1.5537, 1.5456]
d_mape_list_BAY=[3.4909, 3.5360, 3.5173, 3.4834, 3.4716]
d_rmse_list_BAY=[3.5965, 3.6105, 3.6128, 3.5958, 3.6005]

def set_label(rects):
    for rect in rects:
        height = rect.get_height() # 获取⾼度
        plt.text(x = rect.get_x() + rect.get_width()/2, # ⽔平坐标
                 y = height + 0.002, # 竖直坐标
                 s = round(height, 3), # ⽂本
                 ha = 'center', # ⽔平居中
                 fontsize=20, 
                 fontproperties = "Times New Roman")

ax1.set_ylabel("Avg. RMSE", fontdict={"family" : "Times New Roman", "size": 35})
ax1.set_xlabel(r"$M$", fontdict={"family" : "Times New Roman", "size": 45})
ax1.xaxis.set_label_coords(0.5, 1.12)
ax2.set_xlabel(r"$d_m$", fontdict={"family" : "Times New Roman", "size": 45})
ax2.xaxis.set_label_coords(0.5, 1.15)
ax2.set_yticks([])

font = fm.FontProperties(family='Times New Roman', size=30)
for label in ax1.get_xticklabels():
    label.set_fontproperties(font)
for label in ax1.get_yticklabels():
    label.set_fontproperties(font)
for label in ax2.get_xticklabels():
    label.set_fontproperties(font)
for label in ax2.get_yticklabels():
    label.set_fontproperties(font)

# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#63a7f7", "#63a7f7", "#63a7f7", "#bcbd22", "#63a7f7", "#63a7f7"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#0868ac", "#0868ac", "#0868ac", "#bcbd22", "#0868ac", "#0868ac"])
# bar1=plt.bar(d_list, rmse_list, width=0.8, color=["#1f77b4", "#1f77b4", "#1f77b4", "#bcbd22", "#1f77b4", "#1f77b4"])
# bar1=plt.bar(d_list, d_rmse_list_LA, width=0.9, color=["#008080", "#008080", "#008080", "#FFD700", "#008080"])

bar1=ax1.bar(m_list, m_rmse_list_BAY, width=0.9, color=["#00b2ff", "#00b2ff", "#00b2ff", "#00ffa3", "#00b2ff"])
bar2=ax2.bar(d_list, d_rmse_list_BAY, width=0.9, color=["#00b2ff", "#00b2ff", "#00b2ff", "#00ffa3", "#00b2ff"])
ax1.set_ylim(3.5, 3.78)
ax2.set_ylim(3.5, 3.78)

plt.savefig("./param_BAY.png", dpi=300, bbox_inches='tight')
plt.show();

# %%
STASSL=[]
